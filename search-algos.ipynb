# %%
# Linear Search

# %%
def linear_search(arr, item):
    for i in range(len(arr)):
        if arr[i] == item:
            return i
    return -1

# %%
arr = [34,657,123,34,2,0]

# %%
linear_search(arr, 12)
# Out:
# -1

# %%
def binary_search(arr, item):

    l, r = 0, len(arr) - 1

    while l <= r:
        m = l + ((r-l)//2)
        if arr[m] < item:
            l = m + 1
        elif arr[m] > item:
            r = m - 1
        else:
            return m
    return -1

# %%
binary_search(arr, 123)
# Out:
# 2

# %%
# binary search with recursion
def binary_searchRecursion(arr, left, right, item):

    print("left = ", left, "right = ", right, end = ' ')

    if left <= right:

        m = left + ((right - left)//2)

        if arr[m] == item:
            return item

        elif arr[m] < item:
            return binary_search(arr, m + 1, right, item)
        else:
            return binary_search(arr, left, m - 1, item)
    else:
        return -1

# %%
arr = [23,45,78,88,90,100]

# %%
binary_searchRecursion(arr, 0, len(arr)-1, 98)
# Out:
# left =  0 right =  5 left =  3 right =  5 left =  5 right =  5 left =  5 right =  4
# -1

# %%
# Monkey Sort

# %%
def is_sorted(arr):

    sorted = True
    for i in range(len(arr) - 1):
        if arr[i] > arr[i+1]:
            sorted = False
    return sorted

# %%
import random
import time
def monkey_sort(arr):

    while not is_sorted(arr):
        time.sleep(1)
        random.shuffle(arr)
        print(arr)
    print(arr)

# %%
a = [23,4,5,2,677,78,90,1,20]
monkey_sort(a)
# Out:
# [78, 5, 4, 20, 677, 2, 1, 90, 23]
# [1, 20, 23, 5, 677, 2, 4, 90, 78]
# [4, 677, 78, 90, 23, 1, 5, 2, 20]
# [677, 2, 20, 1, 23, 78, 4, 90, 5]
# [78, 677, 5, 23, 1, 20, 90, 4, 2]
# [78, 23, 677, 20, 4, 1, 90, 5, 2]
# [78, 4, 677, 90, 23, 20, 2, 1, 5]
# [23, 4, 2, 78, 1, 20, 5, 677, 90]
# [23, 90, 78, 4, 5, 2, 20, 677, 1]
# [5, 78, 20, 23, 4, 1, 677, 2, 90]
# [2, 4, 90, 5, 78, 23, 677, 1, 20]
# [4, 1, 2, 677, 90, 20, 5, 23, 78]
# [1, 5, 90, 4, 23, 677, 20, 78, 2]
# [20, 23, 78, 2, 1, 677, 5, 90, 4]
# [1, 4, 5, 20, 2, 677, 23, 90, 78]
# [5, 78, 90, 4, 20, 677, 1, 23, 2]
# [23, 5, 78, 677, 2, 4, 1, 20, 90]
# [78, 5, 1, 677, 23, 2, 4, 20, 90]
# [23, 2, 5, 4, 677, 90, 1, 78, 20]
# [677, 5, 23, 78, 4, 20, 1, 90, 2]
# [20, 2, 1, 677, 78, 23, 90, 4, 5]
# [677, 20, 23, 2, 5, 78, 1, 4, 90]
# [4, 20, 78, 677, 5, 2, 1, 23, 90]
# [677, 78, 4, 23, 90, 1, 2, 20, 5]
# [78, 90, 23, 677, 4, 20, 5, 1, 2]
# [4, 90, 677, 5, 20, 1, 23, 78, 2]
# [23, 78, 4, 20, 677, 5, 2, 1, 90]
# ...

# %%
# Bubble Sort #

# %%
def bubble_sort(arr):
    # Number of passes loop
    for i in range (len(arr) - 1):
        flag = 0
        # Number of comparisions in each pass
        for j in range(len(arr) - 1 - i):
            if arr[j] > arr[j + 1]:
                #swap
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                # if swapped
                flag = 1

        #if no swapped occurred
        if flag == 0:
            break

    print(arr)

# %%
bubble_sort(a)
# Out:
# [1, 2, 4, 5, 20, 23, 78, 90, 677]
